# %%
import yfinance as yf
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import math

# %%
def historico(ticker):
    activo = yf.Ticker(ticker)
    return activo.history(period = "max")

# %%
tickers_tec = ['AAPL', 'MSFT', 'GOOGL', 'NVDA', 'META', 'ADBE', 'ORCL', 'CRM', 'INTC', 'AMD']
tickers_com = ['AMZN', 'WMT', 'COST', 'EBAY', 'TGT', 'JD', 'BABA', 'HD', 'LOW', 'M']
tickers_fin = ['JPM', 'BAC', 'GS', 'WFC', 'C', 'AXP', 'V', 'MA', 'BRK-B', 'MS']
tickers_ind = ['BA', 'CAT', 'MMM', 'GE', 'HON', 'DE', 'LMT', 'UPS', 'FDX', 'RTX']
todos = tickers_tec + tickers_com + tickers_fin + tickers_ind
for activo in tickers_tec + tickers_com + tickers_fin + tickers_ind:
    dataframes[activo] = historico(activo)

# %%
def retornos(df):
    df['Retornos'] = np.log(df['Close']/df['Close'].shift(1))
    return df

for activo in dataframes.keys():
    dataframes[activo] = retornos(dataframes[activo])

# %%
import pandas as pd

retornos = {}

# Itera sobre cada acción en el diccionario
for accion in dataframes.keys():
    retornos[accion]=dataframes[accion]["Retornos"]


retornos =pd.DataFrame(retornos)
retornos
# Out:
#                                AAPL      MSFT     GOOGL      NVDA      META  \
# Date
# 1962-01-02 00:00:00-05:00       NaN       NaN       NaN       NaN       NaN
# 1962-01-03 00:00:00-05:00       NaN       NaN       NaN       NaN       NaN
# 1962-01-04 00:00:00-05:00       NaN       NaN       NaN       NaN       NaN
# 1962-01-05 00:00:00-05:00       NaN       NaN       NaN       NaN       NaN
# 1962-01-08 00:00:00-05:00       NaN       NaN       NaN       NaN       NaN
# ...                             ...       ...       ...       ...       ...
# 2024-09-19 00:00:00-04:00  0.036395  0.018126  0.014475  0.038926  0.038563
# 2024-09-20 00:00:00-04:00 -0.002932 -0.007827  0.008903 -0.015992  0.004016
# 2024-09-23 00:00:00-04:00 -0.007610 -0.004052 -0.010693  0.002239  0.005436
# 2024-09-24 00:00:00-04:00  0.003966 -0.010062  0.002715  0.038887 -0.001915
# 2024-09-25 00:00:00-04:00 -0.003834  0.001141 -0.001387  0.020651  0.010559
#
#                                ADBE      ORCL       CRM      INTC       AMD  \
# Date
# 1962-01-02 00:00:00-05:00       NaN       NaN       NaN       NaN       NaN
# 1962-01-03 00:00:00-05:00       NaN       NaN       NaN       NaN       NaN
# 1962-01-04 00:00:00-05:00       NaN       NaN       NaN       NaN       NaN
# 1962-01-05 00:00:00-05:00       NaN       NaN       NaN       NaN       NaN
# 1962-01-08 00:00:00-05:00       NaN       NaN       NaN       NaN       NaN
# ...                             ...       ...       ...       ...       ...
# 2024-09-19 00:00:00-04:00  0.035400  0.018428  0.052325  0.017657  0.055419
# 2024-09-20 00:00:00-04:00 -0.007895  0.002443  0.003041  0.032576 -0.005053
# 2024-09-23 00:00:00-04:00  0.010608 -0.012277 -0.009755  0.032435  0.005117
# 2024-09-24 00:00:00-04:00 -0.007225 -0.000904  0.023306  0.011021  0.009966
# 2024-09-25 00:00:00-04:00 -0.004916  0.010977  0.005108  0.021898  0.007300
#
#                            ...       CAT       MMM        GE       HON  \
# Date                       ...
# 1962-01-02 00:00:00-05:00  ...       NaN       NaN       NaN       NaN
# 1962-01-03 00:00:00-05:00  ...  0.009692  0.007491 -0.010085  0.011198
# 1962-01-04 00:00:00-05:00  ...  0.025399  0.000000 -0.011894  0.006659
# 1962-01-05 00:00:00-05:00  ...  0.009360 -0.026467 -0.025975 -0.002215
# 1962-01-08 00:00:00-05:00  ...  0.006192 -0.005765 -0.001756  0.004425
# ...                        ...       ...       ...       ...       ...
# 2024-09-19 00:00:00-04:00  ...  0.049953  0.003593  0.014119  0.010164
# 2024-09-20 00:00:00-04:00  ... -0.012100  0.006925  0.006799 -0.001720
# 2024-09-23 00:00:00-04:00  ...  0.006351  0.006435  0.006594  0.002063
# 2024-09-24 00:00:00-04:00  ...  0.038996  0.011581  0.005234  0.007334
# 2024-09-25 00:00:00-04:00  ... -0.004753  0.000801  0.002462  0.008199
#
#                                  DE       LMT       UPS       FDX       RTX  \
# Date
# 1962-01-02 00:00:00-05:00       NaN       NaN       NaN       NaN       NaN
# 1962-01-03 00:00:00-05:00       NaN       NaN       NaN       NaN       NaN
# 1962-01-04 00:00:00-05:00       NaN       NaN       NaN       NaN       NaN
# 1962-01-05 00:00:00-05:00       NaN       NaN       NaN       NaN       NaN
# 1962-01-08 00:00:00-05:00       NaN       NaN       NaN       NaN       NaN
# ...                             ...       ...       ...       ...       ...
# 2024-09-19 00:00:00-04:00  0.021362 -0.000548  0.011264  0.007418  0.006586
# 2024-09-20 00:00:00-04:00 -0.009416  0.011855 -0.027079 -0.165231 -0.005655
# 2024-09-23 00:00:00-04:00  0.007511  0.014908  0.001088  0.016166  0.017784
# 2024-09-24 00:00:00-04:00  0.004733 -0.003244  0.006040  0.031718 -0.001914
# 2024-09-25 00:00:00-04:00 -0.001689  0.008141  0.003699 -0.001011  0.011307
#
#                                AMZN
# Date
# 1962-01-02 00:00:00-05:00       NaN
# 1962-01-03 00:00:00-05:00       NaN
# 1962-01-04 00:00:00-05:00       NaN
# 1962-01-05 00:00:00-05:00       NaN
# 1962-01-08 00:00:00-05:00       NaN
# ...                             ...
# 2024-09-19 00:00:00-04:00  0.018284
# 2024-09-20 00:00:00-04:00  0.009070
# 2024-09-23 00:00:00-04:00  0.011830
# 2024-09-24 00:00:00-04:00  0.000413
# 2024-09-25 00:00:00-04:00 -0.006884
#
# [15791 rows x 41 columns]

# %%
# Calcula la matriz de correlación
matriz_correlacion = retornos.corr()
sns.heatmap(matriz_correlacion)
# Out:
# <Axes: >

# %%
def calculo_parametros(df, name = str):
    media = df['Retornos'].mean()
    volatilidad = df['Retornos'].std()
    data = {
        f'Media {name}': [media, media*20, media*250],
        f'Volatilidad {name}':[volatilidad, volatilidad*(20**(1/2)), volatilidad*(250**(1/2))]
        }
    return pd.DataFrame(data, index=['Diario', 'Mensual', 'Anual']).transpose()


parametros = pd.DataFrame()

for activo in dataframes:
    df = calculo_parametros(dataframes[activo], activo)
    parametros = pd.concat([parametros, df], axis = 0)

# %%
parametros
# Out:
#                     Diario   Mensual     Anual
# Media AAPL        0.000701  0.014018  0.175228
# Volatilidad AAPL  0.028272  0.126436  0.447019
# Media MSFT        0.000914  0.018283  0.228537
# Volatilidad MSFT  0.021137  0.094529  0.334209
# Media GOOGL       0.000824  0.016485  0.206058
# ...                    ...       ...       ...
# Volatilidad FDX   0.021348  0.095471  0.337542
# Media RTX         0.000456  0.009124  0.114045
# Volatilidad RTX   0.017539  0.078438  0.277321
# Media AMZN        0.001102  0.022032  0.275396
# Volatilidad AMZN  0.034905  0.156100  0.551897
#
# [82 rows x 3 columns]

# %%
def precio_futuro(precio_spot, promedio_diario, volatilidad_diaria, normalidad):
    return precio_spot*math.e**(promedio_diario*1+ volatilidad_diaria*math.sqrt(1)*normalidad)

def pronostico(ticker, cantidad_dias, cantidad_pronosticos):
    array = np.array([[float(dataframes[ticker]['Close'][-1]) for i in range(cantidad_pronosticos)]])

    for i in range(cantidad_dias):
        
        resultado = np.array([precio_futuro(float(spot), #precio actual
                                float(parametros.loc[f'Media {ticker}', 'Diario']), #media
                                float(parametros.loc[f'Volatilidad {ticker}', 'Diario']), #volatilidad
                                float(np.random.randn(1)[0]))#numero aleatorio de la distribución normal 
                                for spot in array[-1]])#selecciona el ultimo resultado y calcula uno nuevo

        array = np.append(array, [resultado], axis = 0)
    return array

# %%
pronosticos = {}
for activo in dataframes.keys():
    pronosticos[activo] = pd.DataFrame(pronostico(activo, 90, 2000))
# Out:
# C:\Users\esteb\AppData\Local\Temp\ipykernel_13456\3797000713.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   array = np.array([[float(dataframes[ticker]['Close'][-1]) for i in range(cantidad_pronosticos)]])

# %%
def max_min_PnL(ticker, diccionario):
    media = diccionario[ticker].transpose().mean()
    volatilidad = diccionario[ticker].transpose().std()
    ls = media+(volatilidad*2)
    li = media-(volatilidad*2)
    return pd.DataFrame({'Media': media,
            'lim sup': ls,
            'lim inf': li})

max_min = {}
for activo in pronosticos:
    max_min[activo] = max_min_PnL(activo, pronosticos)

# %%
fig, axes = plt.subplots(8, 5, figsize=(15, 20))
a=0
for i, ax in enumerate(axes.flatten()):
    
    sns.lineplot(data=max_min[todos[a]], ax=ax)
    ax.set_title(f'Gráfico {todos[a]}')  
    a+=1

# %%
def porcentajes(activo):
    min_porcentaje = (1 - max_min[activo]['lim inf'][90]/max_min[activo]['Media'][0])*100
    max_porcentaje = (max_min[activo]['lim sup'][90]/max_min[activo]['Media'][0] - 1)*100
    return min_porcentaje, max_porcentaje

porcentaje_perdida_ganancia = pd.DataFrame({}, index = ['% perdida máxima', '% ganacia máxima'])

for activo in max_min.keys():
    min_porcentaje, max_porcentaje = porcentajes(activo)
    porcentaje_perdida_ganancia[activo] = [min_porcentaje, max_porcentaje]

porcentaje_perdida_ganancia = porcentaje_perdida_ganancia.transpose()

porcentaje_perdida_ganancia['diferencia gan-per'] = porcentaje_perdida_ganancia['% ganacia máxima']-porcentaje_perdida_ganancia['% perdida máxima']

# %%
porcentaje_perdida_ganancia
# Out:
#        % perdida máxima  % ganacia máxima  diferencia gan-per
# AAPL          49.786365         71.120217           21.333852
# MSFT          34.277837         55.835714           21.557877
# GOOGL         30.246666         50.232348           19.985682
# NVDA          70.806504        112.999092           42.192588
# META          42.906602         66.612788           23.706186
# ADBE          52.962527         78.438108           25.475581
# ORCL          54.091857         77.184529           23.092673
# CRM           45.016752         66.032803           21.016050
# INTC          43.679951         57.090651           13.410700
# AMD           67.934399         91.287892           23.353493
# AMZ         1064.872457       1290.889447          226.016991
# WMT           29.286491         45.408620           16.122129
# COST          33.514097         46.222611           12.708513
# EBAY          56.159776         75.347795           19.188019
# TGT           34.710592         48.957887           14.247295
# JD            57.409757         71.314057           13.904300
# BABA          48.189749         55.615480            7.425731
# HD            37.011380         58.986313           21.974933
# LOW           38.628234         54.008050           15.379816
# M             52.680476         63.910795           11.230319
# JPM           40.002045         54.852195           14.850150
# BAC           43.208304         53.474641           10.266337
# GS            40.985340         51.337567           10.352227
# WFC           36.552403         48.604901           12.052499
# C             46.782647         54.307018            7.524371
# AXP           38.182987         50.439257           12.256270
# V             29.286738         46.366778           17.080040
# MA            33.479539         55.342160           21.862621
# BRK-B         23.225489         32.145239            8.919750
# MS            49.846043         64.867790           15.021747
# BA            36.521332         48.521614           12.000282
# CAT           32.770703         41.864664            9.093961
# MMM           25.542872         32.364610            6.821738
# GE            28.692308         39.511530           10.819222
# HON           31.148679         40.754828            9.606149
# DE            33.599265         45.892302           12.293037
# LMT           31.759912         45.414192           13.654280
# UPS           28.372979         33.507005            5.134026
# FDX           36.222354         50.777930           14.555576
# RTX           29.702433         39.922904           10.220471
# AMZN          63.441871         93.422368           29.980498
